# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
import missingno as msno
from yellowbrick.classifier import ROCAUC
from yellowbrick.classifier import ConfusionMatrix

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix,precision_score, recall_score, f1_score


from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier


from sklearn.linear_model import LogisticRegression, SGDClassifier

# %%
raw_data = pd.read_csv('data/all_banks_after2010Q3.csv', index_col = 0)

# %%
len(raw_data.index)
# Out:
# 7233

# %%
msno.matrix(raw_data)

# %%
raw_set = raw_data.dropna()
len(raw_set)
# Out:
# 7119

# %%
msno.matrix(raw_set)

# %%
plt.figure(figsize=(12, 8))
sns.distplot(raw_set["Total assets"], bins=50)

# %%
len(raw_set.loc[raw_set.Target == 1])
# Out:
# 137

# %%
raw_set.describe()
# Out:
#        Total equity capital  Total assets   Total loans  \
# count          7.119000e+03  7.119000e+03  7.119000e+03
# mean           4.979489e+04  4.532735e+05  2.965860e+05
# std            3.499014e+05  2.425418e+06  1.843324e+06
# min           -1.035900e+05  1.459000e+03  0.000000e+00
# 25%            7.504000e+03  7.205200e+04  4.201050e+04
# 50%            1.478000e+04  1.479450e+05  9.423500e+04
# 75%            3.166750e+04  3.205235e+05  2.109615e+05
# max            2.328585e+07  1.436089e+08  1.237239e+08
#
#        1-4 family residential loans  Other real estate loans  \
# count                  7.119000e+03             7.119000e+03
# mean                   8.478723e+04             1.200103e+05
# std                    6.452886e+05             4.053811e+05
# min                    0.000000e+00             0.000000e+00
# 25%                    8.066500e+03             1.286150e+04
# 50%                    2.253900e+04             3.867400e+04
# ...

# %%
y = raw_set['Target']
X = raw_set.drop(['Target', 'AsOfDate'], axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1, stratify=y)

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train_std = scaler.transform(X_train)
X_test_std = scaler.transform(X_test)

# %%
log_reg = LogisticRegression(random_state=1)
log_reg.fit(X_train_std,y_train)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=1, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
log_reg.coef_
# Out:
# array([[-6.4405675 , -0.19897017,  0.5972981 ,  1.22916964,  0.27396814,
#          0.52819582,  0.09161907,  0.6740738 , -2.17380453, -1.2280554 ,
#         -1.76169523,  1.13966541, -0.68254433,  1.02082728]])

# %%
log_reg.score(X_train_std, y_train)
# Out:
# 0.9815627743634767

# %%
log_reg.score(X_test_std, y_test)
# Out:
# 0.9789325842696629

# %%
sgd_clf = SGDClassifier(random_state=1)
sgd_clf.fit(X_train_std, y_train)
# Out:
# SGDClassifier(alpha=0.0001, average=False, class_weight=None,
#               early_stopping=False, epsilon=0.1, eta0=0.0, fit_intercept=True,
#               l1_ratio=0.15, learning_rate='optimal', loss='hinge',
#               max_iter=1000, n_iter_no_change=5, n_jobs=None, penalty='l2',
#               power_t=0.5, random_state=1, shuffle=True, tol=0.001,
#               validation_fraction=0.1, verbose=0, warm_start=False)

# %%
sgd_clf.score(X_train_std, y_train)
# Out:
# 0.9826163301141352

# %%
sgd_clf.score(X_test_std, y_test)
# Out:
# 0.9845505617977528

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(sgd_clf, X_train_std, y_train, cv=3, scoring='accuracy')
# Out:
# array([0.98051606, 0.98209584, 0.97891407])

# %%
cross_val_score(log_reg, X_train_std, y_train, cv=3, scoring='accuracy')
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# array([0.98262243, 0.97946288, 0.98102267])

# %%
# Accuracy score is generally not a good performance measure for classifiers, especially when you are dealing with 
# skewed datasets (when some classes are much more frequent than others) -- check with confusing matrix below:
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix
sgd_y_train_pred = cross_val_predict(sgd_clf, X_train_std, y_train, cv=3)
confusion_matrix(y_train, sgd_y_train_pred)
# Out:
# array([[5565,   20],
#        [  91,   19]])

# %%
# Same terrible results for logit regression:
log_y_train_pred = cross_val_predict(log_reg, X_train_std, y_train, cv=3)
confusion_matrix(y_train, log_y_train_pred)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# array([[5578,    7],
#        [ 101,    9]])

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
precision_score(y_train, sgd_y_train_pred) #SGD precision
# Out:
# 0.48717948717948717

# %%
precision_score(y_train, log_y_train_pred) #Logit precision
# Out:
# 0.5625

# %%
recall_score(y_train, sgd_y_train_pred) #SGD precision
# Out:
# 0.17272727272727273

# %%
recall_score(y_train, log_y_train_pred) #Logit recall
# Out:
# 0.08181818181818182

# %%
f1_score(y_train, log_y_train_pred)
# Out:
# 0.14285714285714285

# %%
f1_score(y_train, sgd_y_train_pred)
# Out:
# 0.2550335570469799

# %%
# Precision/Recall tradeoff 
from sklearn.metrics import precision_recall_curve

sgd_y_scores = cross_val_predict(sgd_clf, X_train_std, y_train, cv=3, method='decision_function')
sgd_precisions, sgd_recalls, sgd_thresholds = precision_recall_curve(y_train, sgd_y_scores)

# %%
 #Represent Precision and Recall graphically
def plot_precision_recall(precisions, recalls, thresholds):
    plt.plot(thresholds, precisions[: -1], 'b--', label='Precision')
    plt.plot(thresholds, recalls[: -1], 'g-', label='Recall')
    plt.xlabel('Threshold')
    plt.legend(loc='center left')
    plt.ylim([0,1])

plot_precision_recall(sgd_precisions, sgd_recalls, sgd_thresholds)
plt.show()

# %%
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_train, sgd_y_scores)

# %%
def plot_roc_curve(fpr, tpr, label=None):
    plt.plot(fpr, tpr, linewidth=2, label=label)
    plt.plot([0,1], [0,1], 'k--')
    plt.axis([0,1,0,1])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Negatove Rate')
plot_roc_curve(fpr, tpr)

# %%
# Try trees and random forest

# %%
#Basic DecisionTreeClassifier
dtr_clf = DecisionTreeClassifier()
dtr_clf.fit(X_train_std, y_train)
print('DecisionTreeClassifier -- training score: ', dtr_clf.score(X_train_std, y_train), 'testing score: ', dtr_clf.score(X_test_std, y_test))
# Out:
# DecisionTreeClassifier -- training score:  0.9968393327480246 testing score:  0.9789325842696629

# %%
y_dtr_predict = dtr_clf.predict(X_test_std)
cm = confusion_matrix(y_test, y_dtr_predict)
# DecisionTreeClassifier confusion matrix
y_dtr_predict = dtr_clf.predict(X_test_std)
cm = confusion_matrix(y_test, y_dtr_predict)
cm_df = pd.DataFrame(cm, columns=['predict_neg', 'predict_pos'], index=['actual_neg', 'actual_pos'])
cm_df
# Out:
#             predict_neg  predict_pos
# actual_neg         1380           17
# actual_pos           13           14

# %%
precision_score(y_test, y_dtr_predict) #
# Out:
# 0.45161290322580644

# %%
recall_score(y_test, y_dtr_predict)
# Out:
# 0.5185185185185185

# %%
f1_score(y_test, y_dtr_predict)
# Out:
# 0.48275862068965514

# %%
y_dtr_scores = cross_val_predict(dtr_clf, X_train_std, y_train, cv=3)
dtr_precisions, dtr_recalls, dtr_thresholds = precision_recall_curve(y_train, y_dtr_scores)
#Represent Precision and Recall graphically
plot_precision_recall(dtr_precisions, dtr_recalls, dtr_thresholds)
plt.show()

# %%
dtr_fpr, dtr_tpr, dtr_thresholds = roc_curve(y_train, y_dtr_scores)
plot_roc_curve(dtr_fpr, dtr_tpr)

# %%
# Advanced RandomForestClassifier
rdf_clf = RandomForestClassifier()
rdf_clf.fit(X_train_std, y_train)
print('RandomForestClassifier -- training score: ', rdf_clf.score(X_train_std, y_train), 'testing score: ', rdf_clf.score(X_test_std, y_test))
# Out:
# RandomForestClassifier -- training score:  0.9950834064969272 testing score:  0.9824438202247191
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
# DecisionTreeClassifier confusion matrix
y_rdf_predict = dtr_clf.predict(X_test_std)
cm_rdf = confusion_matrix(y_test, y_dtr_predict)
cm_rdf_df = pd.DataFrame(cm, columns=['predict_neg', 'predict_pos'], index=['actual_neg', 'actual_pos'])
cm_rdf_df
# Out:
#             predict_neg  predict_pos
# actual_neg         1380           17
# actual_pos           13           14

# %%
f1_score(y_test, y_rdf_predict)
# Out:
# 0.48275862068965514

# %%
y_rdf_scores = cross_val_predict(rdf_clf, X_train_std, y_train, cv=3)
rdf_precisions, rdf_recalls, rdf_thresholds = precision_recall_curve(y_train, y_rdf_scores)
#Represent Precision and Recall graphically
plot_precision_recall(rdf_precisions, rdf_recalls, rdf_thresholds)
plt.show()

# %%
rdf_fpr, rdf_tpr, rdf_thresholds = roc_curve(y_train, y_rdf_scores)
plot_roc_curve(rdf_fpr, rdf_tpr)
