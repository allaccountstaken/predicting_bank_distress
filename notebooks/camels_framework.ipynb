# %%
# Important notes on CAMELS valuation framework, consider feature eng to add lagged values as well:
# (C)apital adequace can be measure by 
#       1) Total Equity / Total Assets (EQTA)
#       2) Total Equity / Total Loans (EQTL)
#       - consider also risk-weighted capital adequacy ratio
# (A)sset quality
#       3) Non Performing Loans / Total Assets (NPLTA)
#       4) Non Performing Loans / Gross Loans (NPLGL)
#       5) Loan Loss Reserves / Total Assest (LLRTA)
#       6) Loan Loss Reserves / Gross Loans (LLRGL)
#       - consider Net Interest Margin
# (M)anagement quality
#       7) Operating Costs / Net Operating Income (OCNOI)
#       - Operating Expenses / Assets (OEXTA)
# (E)arnings ability
#       8) Net Income / Total Assest (ROA)
#       9) Net Income / Total Equity (ROE)
#      - consider Net Interest Margin
# (L)iquidity, i.e. ability to fulfill its short-term liability
#       10) Total Loans / Total Customer Deposits (TLTD)
#       11) Total Customer Deposits / Total Assest (TDTA)
#        - consider liquid assets to total assets ratio
#        - liquid assets to deposits ratio
# (S)ensitivity to market risk 
#       12) Trading Income / Net Operatin Income (TINOI)
# Condider adding control variables: Assest Size, GDP growth, Inflation, Interest RAtes (3M, 6M, 12M, 36M)

# %%
# Radar charts: https://python-graph-gallery.com/390-basic-radar-chart/

# Libraries
import matplotlib.pyplot as plt
import pandas as pd
from math import pi
 
# CAMELS representation, source: https://en.wikipedia.org/wiki/CAMELS_rating_system
camels_df = pd.DataFrame({
'group': ['A','B','C','D'],
'Capital': [25, 1.5, 30, 4],
'Assets': [29, 10, 9, 34],
'Management': [25, 39, 23, 24],
'Earnings': [22, 31, 33, 14],
'Liquidity': [28, 15, 32, 14],
'Sensitivity': [20, 10, 10, 10]
})
 
# number of variable
categories=list(camels_df)[1:]
N = len(categories)
 
# We are going to plot the first line of the data frame.
# But we need to repeat the first value to close the circular graph:
values=camels_df.loc[0].drop('group').values.flatten().tolist()
values += values[:1]
values
 
# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]
 
# Initialise the spider plot
ax = plt.subplot(111, polar=True)

# Draw one axe per variable + add labels labels yet
plt.xticks(angles[:-1], categories, color='grey', size=10)
 
# Draw ylabels
ax.set_rlabel_position(0)
plt.yticks([10,20,30], ["10","20","30"], color="grey", size=10)
plt.ylim(0,40)
 
# Plot data
ax.plot(angles, values, linewidth=1, linestyle='solid')
 
# Fill area
ax.fill(angles, values, 'b', alpha=0.1)
#plt.title("Example of single period risk profile")
plt.show()

# %%
# Libraries
import matplotlib.pyplot as plt
import pandas as pd
from math import pi
 
# Set data
df = pd.DataFrame({
'group': ['A','B','C','D'],
'Capital': [15, 20, 30, 40],
'Assets': [29, 30, 40, 41],
'Management': [25, 25, 20, 25],
'Earnings': [20, 12, 15, 45],
'Liquidity': [18, 15, 12, 41],
'Sensitivity': [10, 10, 10, 10]
})
 
 
 
# ------- PART 1: Create background
 
# number of variable
categories=list(camels_evo_df)[1:]
N = len(categories)
 
# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]
 
# Initialise the spider plot
ax = plt.subplot(111, polar=True)
 
# If you want the first axis to be on top:
ax.set_theta_offset(pi / 2)
ax.set_theta_direction(-1) #ch
 
# Draw one axe per variable + add labels labels yet
plt.xticks(angles[:-1], categories)
 
# Draw ylabels
ax.set_rlabel_position(0)
plt.yticks([10,20,30], ["10","20","30"], color="grey", size=7)
plt.ylim(0,40)
 
 
 
# Plot each individual = each line of the data
# I don't do a loop, because plotting more than 3 groups makes the chart unreadable
 
# Ind1
values=camels_evo_df.loc[0].drop('group').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="time -3")
ax.fill(angles, values, 'b', alpha=0.1)
 
# Ind2
values=df.loc[1].drop('group').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="time -2")
ax.fill(angles, values, 'r', alpha=0.1)

# Ind3
values=df.loc[2].drop('group').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="time -1")
ax.fill(angles, values, 'g', alpha=0.1)

# Ind4
values=df.loc[3].drop('group').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="fail")
ax.fill(angles, values, 'y', alpha=0.1)

# Add legend
plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))
#plt.title("Example of risk profile evolution")
plt.show()

# %%
# Libraries
import matplotlib.pyplot as plt
import pandas as pd
from math import pi
 
# Set data
df = pd.DataFrame({
'group': ['A','B','C','D'],
'Capital': [15, 20, 30, 35],
'Assets': [29, 30, 40, 35],
'Management': [25, 25, 30, 30],
'Earnings': [20, 12, 30, 35],
'Liquidity': [18, 15, 12, 30],
'Sensitivity': [10, 10, 10, 20]
})
 
 
 
# ------- PART 1: Create background
 
# number of variable
categories=list(camels_evo_df)[1:]
N = len(categories)
 
# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]
 
# Initialise the spider plot
ax = plt.subplot(111, polar=True)
 
# If you want the first axis to be on top:
ax.set_theta_offset(pi / 2)
ax.set_theta_direction(-1) #ch
 
# Draw one axe per variable + add labels labels yet
plt.xticks(angles[:-1], categories)
 
# Draw ylabels
ax.set_rlabel_position(0)
plt.yticks([10,20,30], ["10","20","30"], color="grey", size=7)
plt.ylim(0,40)
 
 
 
# Plot each individual = each line of the data
# I don't do a loop, because plotting more than 3 groups makes the chart unreadable
 
# Ind1
values=camels_evo_df.loc[0].drop('group').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="time -3")
ax.fill(angles, values, 'b', alpha=0.1)
 
# Ind2
values=df.loc[1].drop('group').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="time -2")
ax.fill(angles, values, 'r', alpha=0.1)

# Ind3
values=df.loc[2].drop('group').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="time -1")
ax.fill(angles, values, 'g', alpha=0.1)

# Ind4
values=df.loc[3].drop('group').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="time 0")
ax.fill(angles, values, 'y', alpha=0.1)

# Add legend
plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))
#plt.title("Example of risk profile evolution")
plt.show()
